# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv('height_weight.csv')

# %%
df.head()
# Out:
#    Height  Weight
# 0     190    72.4
# 1     165    53.2
# 2     164    47.9
# 3     184    62.6
# 4     155    40.0

# %%
##scatter plot 
plt.scatter(df['Weight'],df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
#Correlation
df.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.815737
# Weight  0.815737  1.000000

# %%
##seaborn for visualisation
import seaborn as sns
sns.pairplot(df)

# %%
##independent and dependent features
df.head()
# Out:
#    Height  Weight
# 0     190    72.4
# 1     165    53.2
# 2     164    47.9
# 3     184    62.6
# 4     155    40.0

# %%
##Independent and dependent features
X=df[['Height']] ###Independent featues should be data frame or 2D array
np.array(X).shape
# Out:
# (100, 1)

# %%
X_series=df['Height']
np.array(X_series).shape
# Out:
# (100,)

# %%
y=df['Weight'] ##series or 1d array
y
# Out:
# 0     72.4
# 1     53.2
# 2     47.9
# 3     62.6
# 4     40.0
#       ...
# 95    57.9
# 96    40.0
# 97    59.6
# 98    51.6
# 99    56.5
# Name: Weight, Length: 100, dtype: float64

# %%
np.array(y).shape
# Out:
# (100,)

# %%
##Train test split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
##Standardisation
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.24223778],
#        [-0.28174465],
#        [-0.60190903],
#        [ 0.4386252 ],
#        [-1.56240216],
#        [-1.64244325],
#        [ 1.31907723],
#        [ 0.19850191],
#        [ 0.27854301],
#        [ 0.03841973],
#        [-1.24223778],
#        [ 1.55920051],
#        [-1.16219669],
#        [ 1.55920051],
#        [ 0.27854301],
#        [-1.0021145 ],
#        [-0.84203231],
#        [ 1.15899504],
#        [ 0.83883067],
#        [-1.16219669],
#        [ 1.07895395],
#        [ 0.51866629],
#        [-0.52186793],
#        [-1.64244325],
#        [-0.9220734 ],
#        [ 1.23903614],
#        [ 1.07895395],
#        [ 1.39911832],
#        [-0.52186793],
#        [-0.68195012],
#        [-1.0021145 ],
#        [-0.60190903],
#        [ 0.91887176],
#        [ 1.15899504],
#        [ 1.15899504],
#        [ 0.99891285],
#        [ 0.4386252 ],
#        [ 1.39911832],
#        [ 0.67874848],
#        [ 0.91887176],
#        [ 1.39911832],
# ...

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.68195012],
#        [ 0.51866629],
#        [ 0.99891285],
#        [ 1.15899504],
#        [-0.9220734 ],
#        [ 0.3585841 ],
#        [-0.20170356],
#        [-0.84203231],
#        [-0.52186793],
#        [ 1.55920051],
#        [-0.36178575],
#        [-0.84203231],
#        [-0.12166246],
#        [-0.44182684],
#        [-0.52186793],
#        [-1.24223778],
#        [-1.24223778],
#        [ 1.07895395],
#        [-0.84203231],
#        [-0.28174465],
#        [ 0.67874848],
#        [-0.52186793],
#        [-0.20170356],
#        [-0.04162137],
#        [ 1.07895395]])

# %%
##Apply simple linear regression
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("Slope or coefficent:",regression.coef_)
print("Intercept:",regression.intercept_)
# Out:
# Slope or coefficent: [8.12332154]
# Intercept: 52.664

# %%
 #Plot training data best fit line
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# %% [markdown]
# prediction of test data
#
# 1.predicted height output=intercept+coef_(Weights)
# 2.y_pred_rest=170.52+10.16(X_test)

# %%
##Prediction for test data
y_pred=regression.predict(X_test)

# %%
##Performance metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 32.91673057650575
# 4.698101712520671
# 5.737310395691151

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.651437801172978

# %%
1-(1-score)*(len(y_test)-1/(len(y_test)-X_test.shape[1]-1))
# Out:
# -7.69890009246568

# %%
##OLS linear regression

# %%
import statsmodels.api as sm

# %%
model=sm.OLS(y_train,X_train).fit()

# %%
print(model.predict(X_test))
# Out:
# [ -5.53970011   4.21329304   8.1144903    9.41488939  -7.49029874
#    2.91289395  -1.63850285  -6.8400992   -4.23930102  12.66588711
#   -2.93890194  -6.8400992   -0.98830331  -3.58910148  -4.23930102
#  -10.09109692 -10.09109692   8.76468985  -6.8400992   -2.28870239
#    5.51369213  -4.23930102  -1.63850285  -0.33810376   8.76468985]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared (uncentered):                   0.023
# Model:                            OLS   Adj. R-squared (uncentered):              0.010
# Method:                 Least Squares   F-statistic:                              1.739
# Date:                Mon, 21 Sep 2026   Prob (F-statistic):                       0.191
# Time:                        08:46:55   Log-Likelihood:                         -404.17
# No. Observations:                  75   AIC:                                      810.3
# Df Residuals:                      74   BIC:                                      812.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
##Prediction for new data
regression.predict(scaler.transform([[176]]))
# Out:
# C:\Users\KRITHI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([56.2270935])
